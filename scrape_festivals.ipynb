# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import math
# import re

# %%
current_year = 2019

dict_year = {}

venice = {1932:1,
          1934:2,
          1935:3,
          1936:4,
          1937:5,
          1938:6,
          1939:7}
venice.update(zip(range(1947, 1972+1), range(8, 33+1)))
venice.update(zip(range(1979, current_year+1), range(36, (current_year-1979+36)+1)))
venice

berlin = dict(zip(range(1951, current_year+1), range(1, (current_year-1951+1)+1)))

dict_year['venice'] = venice
dict_year['berlin'] = berlin

# %%
def get_urls(festival, from_year, to_year):
    '''
    Return list of tuples with the urls of relevant festival Wikipedia pages up to the current year,
    the corresponding festivals, and the corresponding years.
    
    Keyword arguments:
    festival -- string for which festival, e.g. 'cannes', 'venice', or 'berlin'
    from_year -- the first year in a range of festival years, inclusive
    to_year -- the last year in a range of festival years, inclusive
    Note: The range between from_year and to_year must only include valid years.
    '''
    urls = []
    
    ordinal = lambda n: "%d%s" % (n, 'tsnrhtdd'[(math.floor(n/10)%10!=1)*(n%10<4)*n%10::4]) # from https://stackoverflow.com/questions/9647202/ordinal-numbers-replacement
      
    if festival == 'cannes':
        for year in range(from_year, to_year+1):
            urls.append(('https://en.wikipedia.org/wiki/' + str(year) + '_Cannes_Film_Festival', festival, year))
    elif festival == 'venice':
        for year in range(from_year, to_year+1):
            urls.append(('https://en.wikipedia.org/wiki/' + ordinal(dict_year['venice'][year]) + '_Venice_International_Film_Festival', festival, year))
    else: # berlin
        for year in range(from_year, to_year+1):
            urls.append(('https://en.wikipedia.org/wiki/' + ordinal(dict_year['berlin'][year]) + '_Berlin_International_Film_Festival', festival, year))
    
    return urls

# %%
def get_festival_table(url, festival, year_festival):
    '''
    Return dataframe for festival formatted as table on Wikipedia.
    
    url -- url of the relevant festival
    festival -- string for which festival, e.g. 'cannes', 'venice', or 'berlin'
    year_festival -- the year of the relevant festival
    
    For Cannes, tables[0] is the table of films selected to compete for the Palme d'Or
    For Venice, tables[0] is the table of films selected to compete for the Golden Lion
    For Berlin, tables[0] is the table of films selected to compete for the Golden Bear
    '''
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'lxml')
    tables = soup.findAll('table', {'class': 'wikitable'})
    
    title_english = []
    title_original = []
    director = []
    country = []
    winner = []
    link_film = []
    link_director = []
    
    trs = tables[0].find_all('tr')[1:]
    for tr in trs:
        tds = tr.find_all('td')

        # title_english
        title_english.append(tds[0].find('i').get_text() if tds[0].find('i') else 'N/A')

        # title_original, director, link_film, link_director, country
        if tds[0].has_attr('colspan') and tds[0]['colspan']=='2':
            title_original.append('N/A')
            director.append(tds[1].get_text().strip('\n'))
            link_film.append('https://en.wikipedia.org' + tds[0].find('a').get('href') if tds[0].find('a') else 'N/A')

            links = tds[1].find_all('a')
            links_string = ''
            for link in links:
                links_string += 'https://en.wikipedia.org' + link.get('href') + ' '
            link_director.append(links_string if links else 'N/A')

            country.append(tds[2].get_text().strip('\n'))
        else:
            title_original.append(tds[1].get_text().strip('\n'))
            director.append(tds[2].get_text().strip('\n'))
            if tds[0].find('a'):
                link_film.append('https://en.wikipedia.org' + tds[0].find('a').get('href'))
            elif tds[1].find('a'):
                link_film.append('https://en.wikipedia.org' + tds[1].find('a').get('href'))
            else:
                link_film.append('N/A')

            links = tds[2].find_all('a')
            links_string = ''
            for link in links:
                links_string += 'https://en.wikipedia.org' + link.get('href') + ' '
            link_director.append(links_string if links else 'N/A')

            country.append(tds[3].get_text().strip('\n'))

        # winner
        if tr.has_attr('style'):
            winner.append(1)
        else:
            winner.append(0)

    # replace '' with 'N/A'
    title_original = ['N/A' if t=='' else t for t in title_original]
    director = ['N/A' if d=='' else d for d in director]
    country = ['N/A' if c=='' else c for c in country]
    
    df_tmp = pd.DataFrame({'title_english': title_english,
                           'title_original': title_original,
                           'director': director,
                           'country': country,
                           'winner': winner,
                           'festival': festival,
                           'year_festival': year_festival,
                           'link_film': link_film,
                           'link_director': link_director,})
    
    return df_tmp

# %%
# TWO POSSIBLE TO-DOS: 1) country, 2) films/directors that don't have links (current code sets to 'N/A', which isn't ideal)
def get_festival_bullet(url, festival, year_festival):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'lxml')
    
    title_english = []
    title_original = []
    # country = []
    director = []
    link_film = []
    link_director = []
    
    if festival == 'cannes':
        list_of_films = soup.find('span', {'id': ["In_competition_-_Feature_film", "In_competition_–_Feature_film", "In_competition_-_Feature_films", "Feature_film_competition", "Feature_films_competition", "Films_in_competition"]}).parent.find_next_sibling('div').ul.find_all('li')
    else: # venice
        list_of_films = soup.find('span', {'id': ["In-Competition_films", "Films_premiered"]}).parent.find_next_sibling('ul').find_all('li')
    
    for child in list_of_films:
        
        # title_english
        try:
            title_english.append(child.i.get_text())
        except:
            title_english.append('N/A')
        
        # title_original
        try:
            title_original.append(child.i.find_next_sibling('i').get_text())
        except:
            title_original.append('N/A')

        # link_film
        try:
            link_film.append('https://en.wikipedia.org' + child.i.a['href'])
        except:
            link_film.append('N/A')
        
        # come back to country later b/c venice 1969, 1970, 1971, 1972, 1979 + maybe just use the country in the API
        
        # the following code does not take into account directors that don't have links, but are only found in the HTML text.
        # I have decided to leave out films and directors that don't have links because I will assume that means those directors are less important.
        list_of_directors = child.find_all('a', recursive=False)
        director_string = ''
        link_director_string = ''
        for d in list_of_directors:
            director_string += d.get_text() + ', '
            link_director_string += ('https://en.wikipedia.org' + d['href']) + ' '
        director.append(director_string if list_of_directors else 'N/A')
        link_director.append(link_director_string if list_of_directors else 'N/A')    
        
    director = [d.strip(', ') for d in director]
    link_director = [link.strip(' ') for link in link_director]
    
    if (festival == 'cannes' and year_festival in [1946, 1947, 1951, 1968] or (festival == 'venice')):
        winner = 0
    else:
        palmedor = [] # all links associated to the Palme d'Or
        for child in soup.find('span', {'id': "Official_awards"}).parent.find_next_sibling('ul').find('a', {'title': "Palme d'Or"}).parent.find_all('a'):
            palmedor.append('https://en.wikipedia.org' + child['href'])
        winner = [1 if link in palmedor else 0 for link in link_film]
        
    df_tmp = pd.DataFrame({'title_english': title_english,
                           'title_original': title_original,
                           'director': director,
                           'country': 'N/A',
                           'winner': winner,
                           'festival': festival,
                           'year_festival': year_festival,
                           'link_film': link_film,
                           'link_director': link_director})
     
    return df_tmp

# %%
def get_festival_dfs(urls, data_format):
    '''
    Given urls from get_urls() and the format of the films on Wikipedia,
    return the overall festival dataframe.
    
    urls -- must be from get_urls()
    data_format -- the format of the films on Wikipedia, e.g. 'table', 'bullet'
    '''
    df_festival = pd.DataFrame(columns = ['title_english', 'title_original', 'director', 'country', 'winner', 'festival', 'year_festival', 'link_film', 'link_director'])
    
    for url in urls:
        print(url)
        if(data_format == 'table'):
            df_festival = df_festival.append(get_festival_table(url[0], url[1], url[2]), ignore_index=True)
        else: # bullet
            df_festival = df_festival.append(get_festival_bullet(url[0], url[1], url[2]), ignore_index=True)
    
    return df_festival

# %%
# CANNES
# table: 2007 to 2019, inclusive
# bullet: 1949 ("directed by"), 1952 to 1967, 1969 to 1979, 1981 to 1984, 1986 to 1990, 1992, 1995 to 2006, inclusive
# exceptions: 1946 (films fine, awards manual, "directed by"), 1947 (films fine, awards manual), 1948 (nonexistent), 1950 (nonexistent), 1951 (films fine, awards manual), 1968 (films fine, awards manual), 1980 (diff tag format, manual), 1985 (table), 1991 (table), 1993, (table), 1994 (table)

# VENICE
# table: 1939, 1947 to 1968, 1980 to 2019, inclusive
# bullet: 1932, 1934 to 1938, 1969 to 1972, 1979
# exceptions: 1932 (films not available, so treat as nonexistent, will not include in dataset) 1969 (country), 1970 (country), 1971 (country), 1972 (country), 1979 (country)

urls_table = get_urls('cannes', 1985, 1985) + get_urls('cannes', 1991, 1991) + get_urls('cannes', 1993, 1994) + get_urls('cannes', 2007, 2019) + get_urls('venice', 1939, 1939) + get_urls('venice', 1947, 1968) + get_urls('venice', 1980, 2019) + get_urls('berlin', 1951, 2009) + get_urls('berlin', 2011, 2019)
urls_bullet = get_urls('cannes', 1946, 1947) + get_urls('cannes', 1949, 1949) + get_urls('cannes', 1951, 1979) + get_urls('cannes', 1981, 1984) + get_urls('cannes', 1986, 1990) + get_urls('cannes', 1992, 1992) + get_urls('cannes', 1995, 2006) + get_urls('venice', 1934, 1938) + get_urls('venice', 1969, 1972) + get_urls('venice', 1979, 1979)

df_festival_table = get_festival_dfs(urls_table, 'table')
df_festival_bullet = get_festival_dfs(urls_bullet, 'bullet')

df_festival = df_festival_table.append(df_festival_bullet, ignore_index=True)

df_festival.to_csv('./data/festivals_tmp.csv', index_label='id')
# Out:
# ('https://en.wikipedia.org/wiki/1985_Cannes_Film_Festival', 'cannes', 1985)
# ('https://en.wikipedia.org/wiki/1991_Cannes_Film_Festival', 'cannes', 1991)
# ('https://en.wikipedia.org/wiki/1993_Cannes_Film_Festival', 'cannes', 1993)
# ('https://en.wikipedia.org/wiki/1994_Cannes_Film_Festival', 'cannes', 1994)
# ('https://en.wikipedia.org/wiki/2007_Cannes_Film_Festival', 'cannes', 2007)
# ('https://en.wikipedia.org/wiki/2008_Cannes_Film_Festival', 'cannes', 2008)
# ('https://en.wikipedia.org/wiki/2009_Cannes_Film_Festival', 'cannes', 2009)
# ('https://en.wikipedia.org/wiki/2010_Cannes_Film_Festival', 'cannes', 2010)
# ('https://en.wikipedia.org/wiki/2011_Cannes_Film_Festival', 'cannes', 2011)
# ('https://en.wikipedia.org/wiki/2012_Cannes_Film_Festival', 'cannes', 2012)
# ('https://en.wikipedia.org/wiki/2013_Cannes_Film_Festival', 'cannes', 2013)
# ('https://en.wikipedia.org/wiki/2014_Cannes_Film_Festival', 'cannes', 2014)
# ('https://en.wikipedia.org/wiki/2015_Cannes_Film_Festival', 'cannes', 2015)
# ('https://en.wikipedia.org/wiki/2016_Cannes_Film_Festival', 'cannes', 2016)
# ('https://en.wikipedia.org/wiki/2017_Cannes_Film_Festival', 'cannes', 2017)
# ('https://en.wikipedia.org/wiki/2018_Cannes_Film_Festival', 'cannes', 2018)
# ('https://en.wikipedia.org/wiki/2019_Cannes_Film_Festival', 'cannes', 2019)
# ('https://en.wikipedia.org/wiki/7th_Venice_International_Film_Festival', 'venice', 1939)
# ('https://en.wikipedia.org/wiki/8th_Venice_International_Film_Festival', 'venice', 1947)
# ('https://en.wikipedia.org/wiki/9th_Venice_International_Film_Festival', 'venice', 1948)
# ('https://en.wikipedia.org/wiki/10th_Venice_International_Film_Festival', 'venice', 1949)
# ('https://en.wikipedia.org/wiki/11th_Venice_International_Film_Festival', 'venice', 1950)
# ('https://en.wikipedia.org/wiki/12th_Venice_International_Film_Festival', 'venice', 1951)
# ('https://en.wikipedia.org/wiki/13th_Venice_International_Film_Festival', 'venice', 1952)
# ('https://en.wikipedia.org/wiki/14th_Venice_International_Film_Festival', 'venice', 1953)
# ('https://en.wikipedia.org/wiki/15th_Venice_International_Film_Festival', 'venice', 1954)
# ('https://en.wikipedia.org/wiki/16th_Venice_International_Film_Festival', 'venice', 1955)
# ('https://en.wikipedia.org/wiki/17th_Venice_International_Film_Festival', 'venice', 1956)
# ('https://en.wikipedia.org/wiki/18th_Venice_International_Film_Festival', 'venice', 1957)
# ('https://en.wikipedia.org/wiki/19th_Venice_International_Film_Festival', 'venice', 1958)
# ('https://en.wikipedia.org/wiki/20th_Venice_International_Film_Festival', 'venice', 1959)
# ('https://en.wikipedia.org/wiki/21st_Venice_International_Film_Festival', 'venice', 1960)
# ('https://en.wikipedia.org/wiki/22nd_Venice_International_Film_Festival', 'venice', 1961)
# ('https://en.wikipedia.org/wiki/23rd_Venice_International_Film_Festival', 'venice', 1962)
# ('https://en.wikipedia.org/wiki/24th_Venice_International_Film_Festival', 'venice', 1963)
# ('https://en.wikipedia.org/wiki/25th_Venice_International_Film_Festival', 'venice', 1964)
# ('https://en.wikipedia.org/wiki/26th_Venice_International_Film_Festival', 'venice', 1965)
# ('https://en.wikipedia.org/wiki/27th_Venice_International_Film_Festival', 'venice', 1966)
# ('https://en.wikipedia.org/wiki/28th_Venice_International_Film_Festival', 'venice', 1967)
# ('https://en.wikipedia.org/wiki/29th_Venice_International_Film_Festival', 'venice', 1968)
# ('https://en.wikipedia.org/wiki/37th_Venice_International_Film_Festival', 'venice', 1980)
# ('https://en.wikipedia.org/wiki/38th_Venice_International_Film_Festival', 'venice', 1981)
# ('https://en.wikipedia.org/wiki/39th_Venice_International_Film_Festival', 'venice', 1982)
# ('https://en.wikipedia.org/wiki/40th_Venice_International_Film_Festival', 'venice', 1983)
# ('https://en.wikipedia.org/wiki/41st_Venice_International_Film_Festival', 'venice', 1984)
# ('https://en.wikipedia.org/wiki/42nd_Venice_International_Film_Festival', 'venice', 1985)
# ('https://en.wikipedia.org/wiki/43rd_Venice_International_Film_Festival', 'venice', 1986)
# ('https://en.wikipedia.org/wiki/44th_Venice_International_Film_Festival', 'venice', 1987)
# ('https://en.wikipedia.org/wiki/45th_Venice_International_Film_Festival', 'venice', 1988)
# ('https://en.wikipedia.org/wiki/46th_Venice_International_Film_Festival', 'venice', 1989)
# ('https://en.wikipedia.org/wiki/47th_Venice_International_Film_Festival', 'venice', 1990)
# ('https://en.wikipedia.org/wiki/48th_Venice_International_Film_Festival', 'venice', 1991)
# ('https://en.wikipedia.org/wiki/49th_Venice_International_Film_Festival', 'venice', 1992)
# ('https://en.wikipedia.org/wiki/50th_Venice_International_Film_Festival', 'venice', 1993)
# ('https://en.wikipedia.org/wiki/51st_Venice_International_Film_Festival', 'venice', 1994)
# ('https://en.wikipedia.org/wiki/52nd_Venice_International_Film_Festival', 'venice', 1995)
# ('https://en.wikipedia.org/wiki/53rd_Venice_International_Film_Festival', 'venice', 1996)
# ('https://en.wikipedia.org/wiki/54th_Venice_International_Film_Festival', 'venice', 1997)
# ('https://en.wikipedia.org/wiki/55th_Venice_International_Film_Festival', 'venice', 1998)
# ('https://en.wikipedia.org/wiki/56th_Venice_International_Film_Festival', 'venice', 1999)
# ('https://en.wikipedia.org/wiki/57th_Venice_International_Film_Festival', 'venice', 2000)
# ('https://en.wikipedia.org/wiki/58th_Venice_International_Film_Festival', 'venice', 2001)
# ('https://en.wikipedia.org/wiki/59th_Venice_International_Film_Festival', 'venice', 2002)
# ('https://en.wikipedia.org/wiki/60th_Venice_International_Film_Festival', 'venice', 2003)
# ('https://en.wikipedia.org/wiki/61st_Venice_International_Film_Festival', 'venice', 2004)
# ('https://en.wikipedia.org/wiki/62nd_Venice_International_Film_Festival', 'venice', 2005)
# ('https://en.wikipedia.org/wiki/63rd_Venice_International_Film_Festival', 'venice', 2006)
# ('https://en.wikipedia.org/wiki/64th_Venice_International_Film_Festival', 'venice', 2007)
# ('https://en.wikipedia.org/wiki/65th_Venice_International_Film_Festival', 'venice', 2008)
# ('https://en.wikipedia.org/wiki/66th_Venice_International_Film_Festival', 'venice', 2009)
# ('https://en.wikipedia.org/wiki/67th_Venice_International_Film_Festival', 'venice', 2010)
# ('https://en.wikipedia.org/wiki/68th_Venice_International_Film_Festival', 'venice', 2011)
# ('https://en.wikipedia.org/wiki/69th_Venice_International_Film_Festival', 'venice', 2012)
# ('https://en.wikipedia.org/wiki/70th_Venice_International_Film_Festival', 'venice', 2013)
# ('https://en.wikipedia.org/wiki/71st_Venice_International_Film_Festival', 'venice', 2014)
# ('https://en.wikipedia.org/wiki/72nd_Venice_International_Film_Festival', 'venice', 2015)
# ('https://en.wikipedia.org/wiki/73rd_Venice_International_Film_Festival', 'venice', 2016)
# ('https://en.wikipedia.org/wiki/74th_Venice_International_Film_Festival', 'venice', 2017)
# ('https://en.wikipedia.org/wiki/75th_Venice_International_Film_Festival', 'venice', 2018)
# ('https://en.wikipedia.org/wiki/76th_Venice_International_Film_Festival', 'venice', 2019)
# ('https://en.wikipedia.org/wiki/1st_Berlin_International_Film_Festival', 'berlin', 1951)
# ('https://en.wikipedia.org/wiki/2nd_Berlin_International_Film_Festival', 'berlin', 1952)
# ('https://en.wikipedia.org/wiki/3rd_Berlin_International_Film_Festival', 'berlin', 1953)
# ('https://en.wikipedia.org/wiki/4th_Berlin_International_Film_Festival', 'berlin', 1954)
# ('https://en.wikipedia.org/wiki/5th_Berlin_International_Film_Festival', 'berlin', 1955)
# ('https://en.wikipedia.org/wiki/6th_Berlin_International_Film_Festival', 'berlin', 1956)
# ('https://en.wikipedia.org/wiki/7th_Berlin_International_Film_Festival', 'berlin', 1957)
# ('https://en.wikipedia.org/wiki/8th_Berlin_International_Film_Festival', 'berlin', 1958)
# ('https://en.wikipedia.org/wiki/9th_Berlin_International_Film_Festival', 'berlin', 1959)
# ('https://en.wikipedia.org/wiki/10th_Berlin_International_Film_Festival', 'berlin', 1960)
# ('https://en.wikipedia.org/wiki/11th_Berlin_International_Film_Festival', 'berlin', 1961)
# ('https://en.wikipedia.org/wiki/12th_Berlin_International_Film_Festival', 'berlin', 1962)
# ('https://en.wikipedia.org/wiki/13th_Berlin_International_Film_Festival', 'berlin', 1963)
# ('https://en.wikipedia.org/wiki/14th_Berlin_International_Film_Festival', 'berlin', 1964)
# ('https://en.wikipedia.org/wiki/15th_Berlin_International_Film_Festival', 'berlin', 1965)
# ('https://en.wikipedia.org/wiki/16th_Berlin_International_Film_Festival', 'berlin', 1966)
# ('https://en.wikipedia.org/wiki/17th_Berlin_International_Film_Festival', 'berlin', 1967)
# ('https://en.wikipedia.org/wiki/18th_Berlin_International_Film_Festival', 'berlin', 1968)
# ('https://en.wikipedia.org/wiki/19th_Berlin_International_Film_Festival', 'berlin', 1969)
# ('https://en.wikipedia.org/wiki/20th_Berlin_International_Film_Festival', 'berlin', 1970)
# ('https://en.wikipedia.org/wiki/21st_Berlin_International_Film_Festival', 'berlin', 1971)
# ('https://en.wikipedia.org/wiki/22nd_Berlin_International_Film_Festival', 'berlin', 1972)
# ('https://en.wikipedia.org/wiki/23rd_Berlin_International_Film_Festival', 'berlin', 1973)
# ('https://en.wikipedia.org/wiki/24th_Berlin_International_Film_Festival', 'berlin', 1974)
# ('https://en.wikipedia.org/wiki/25th_Berlin_International_Film_Festival', 'berlin', 1975)
# ('https://en.wikipedia.org/wiki/26th_Berlin_International_Film_Festival', 'berlin', 1976)
# ('https://en.wikipedia.org/wiki/27th_Berlin_International_Film_Festival', 'berlin', 1977)
# ('https://en.wikipedia.org/wiki/28th_Berlin_International_Film_Festival', 'berlin', 1978)
# ('https://en.wikipedia.org/wiki/29th_Berlin_International_Film_Festival', 'berlin', 1979)
# ('https://en.wikipedia.org/wiki/30th_Berlin_International_Film_Festival', 'berlin', 1980)
# ('https://en.wikipedia.org/wiki/31st_Berlin_International_Film_Festival', 'berlin', 1981)
# ('https://en.wikipedia.org/wiki/32nd_Berlin_International_Film_Festival', 'berlin', 1982)
# ('https://en.wikipedia.org/wiki/33rd_Berlin_International_Film_Festival', 'berlin', 1983)
# ('https://en.wikipedia.org/wiki/34th_Berlin_International_Film_Festival', 'berlin', 1984)
# ('https://en.wikipedia.org/wiki/35th_Berlin_International_Film_Festival', 'berlin', 1985)
# ('https://en.wikipedia.org/wiki/36th_Berlin_International_Film_Festival', 'berlin', 1986)
# ('https://en.wikipedia.org/wiki/37th_Berlin_International_Film_Festival', 'berlin', 1987)
# ('https://en.wikipedia.org/wiki/38th_Berlin_International_Film_Festival', 'berlin', 1988)
# ('https://en.wikipedia.org/wiki/39th_Berlin_International_Film_Festival', 'berlin', 1989)
# ('https://en.wikipedia.org/wiki/40th_Berlin_International_Film_Festival', 'berlin', 1990)
# ('https://en.wikipedia.org/wiki/41st_Berlin_International_Film_Festival', 'berlin', 1991)
# ('https://en.wikipedia.org/wiki/42nd_Berlin_International_Film_Festival', 'berlin', 1992)
# ('https://en.wikipedia.org/wiki/43rd_Berlin_International_Film_Festival', 'berlin', 1993)
# ('https://en.wikipedia.org/wiki/44th_Berlin_International_Film_Festival', 'berlin', 1994)
# ('https://en.wikipedia.org/wiki/45th_Berlin_International_Film_Festival', 'berlin', 1995)
# ('https://en.wikipedia.org/wiki/46th_Berlin_International_Film_Festival', 'berlin', 1996)
# ('https://en.wikipedia.org/wiki/47th_Berlin_International_Film_Festival', 'berlin', 1997)
# ('https://en.wikipedia.org/wiki/48th_Berlin_International_Film_Festival', 'berlin', 1998)
# ('https://en.wikipedia.org/wiki/49th_Berlin_International_Film_Festival', 'berlin', 1999)
# ('https://en.wikipedia.org/wiki/50th_Berlin_International_Film_Festival', 'berlin', 2000)
# ('https://en.wikipedia.org/wiki/51st_Berlin_International_Film_Festival', 'berlin', 2001)
# ('https://en.wikipedia.org/wiki/52nd_Berlin_International_Film_Festival', 'berlin', 2002)
# ('https://en.wikipedia.org/wiki/53rd_Berlin_International_Film_Festival', 'berlin', 2003)
# ('https://en.wikipedia.org/wiki/54th_Berlin_International_Film_Festival', 'berlin', 2004)
# ('https://en.wikipedia.org/wiki/55th_Berlin_International_Film_Festival', 'berlin', 2005)
# ('https://en.wikipedia.org/wiki/56th_Berlin_International_Film_Festival', 'berlin', 2006)
# ('https://en.wikipedia.org/wiki/57th_Berlin_International_Film_Festival', 'berlin', 2007)
# ('https://en.wikipedia.org/wiki/58th_Berlin_International_Film_Festival', 'berlin', 2008)
# ('https://en.wikipedia.org/wiki/59th_Berlin_International_Film_Festival', 'berlin', 2009)
# ('https://en.wikipedia.org/wiki/61st_Berlin_International_Film_Festival', 'berlin', 2011)
# ('https://en.wikipedia.org/wiki/62nd_Berlin_International_Film_Festival', 'berlin', 2012)
# ('https://en.wikipedia.org/wiki/63rd_Berlin_International_Film_Festival', 'berlin', 2013)
# ('https://en.wikipedia.org/wiki/64th_Berlin_International_Film_Festival', 'berlin', 2014)
# ('https://en.wikipedia.org/wiki/65th_Berlin_International_Film_Festival', 'berlin', 2015)
# ('https://en.wikipedia.org/wiki/66th_Berlin_International_Film_Festival', 'berlin', 2016)
# ('https://en.wikipedia.org/wiki/67th_Berlin_International_Film_Festival', 'berlin', 2017)
# ('https://en.wikipedia.org/wiki/68th_Berlin_International_Film_Festival', 'berlin', 2018)
# ('https://en.wikipedia.org/wiki/69th_Berlin_International_Film_Festival', 'berlin', 2019)
# ('https://en.wikipedia.org/wiki/1946_Cannes_Film_Festival', 'cannes', 1946)
# ('https://en.wikipedia.org/wiki/1947_Cannes_Film_Festival', 'cannes', 1947)
# ('https://en.wikipedia.org/wiki/1949_Cannes_Film_Festival', 'cannes', 1949)
# ('https://en.wikipedia.org/wiki/1951_Cannes_Film_Festival', 'cannes', 1951)
# ('https://en.wikipedia.org/wiki/1952_Cannes_Film_Festival', 'cannes', 1952)
# ('https://en.wikipedia.org/wiki/1953_Cannes_Film_Festival', 'cannes', 1953)
# ('https://en.wikipedia.org/wiki/1954_Cannes_Film_Festival', 'cannes', 1954)
# ('https://en.wikipedia.org/wiki/1955_Cannes_Film_Festival', 'cannes', 1955)
# ('https://en.wikipedia.org/wiki/1956_Cannes_Film_Festival', 'cannes', 1956)
# ('https://en.wikipedia.org/wiki/1957_Cannes_Film_Festival', 'cannes', 1957)
# ('https://en.wikipedia.org/wiki/1958_Cannes_Film_Festival', 'cannes', 1958)
# ('https://en.wikipedia.org/wiki/1959_Cannes_Film_Festival', 'cannes', 1959)
# ('https://en.wikipedia.org/wiki/1960_Cannes_Film_Festival', 'cannes', 1960)
# ('https://en.wikipedia.org/wiki/1961_Cannes_Film_Festival', 'cannes', 1961)
# ('https://en.wikipedia.org/wiki/1962_Cannes_Film_Festival', 'cannes', 1962)
# ('https://en.wikipedia.org/wiki/1963_Cannes_Film_Festival', 'cannes', 1963)
# ('https://en.wikipedia.org/wiki/1964_Cannes_Film_Festival', 'cannes', 1964)
# ('https://en.wikipedia.org/wiki/1965_Cannes_Film_Festival', 'cannes', 1965)
# ('https://en.wikipedia.org/wiki/1966_Cannes_Film_Festival', 'cannes', 1966)
# ('https://en.wikipedia.org/wiki/1967_Cannes_Film_Festival', 'cannes', 1967)
# ('https://en.wikipedia.org/wiki/1968_Cannes_Film_Festival', 'cannes', 1968)
# ('https://en.wikipedia.org/wiki/1969_Cannes_Film_Festival', 'cannes', 1969)
# ('https://en.wikipedia.org/wiki/1970_Cannes_Film_Festival', 'cannes', 1970)
# ('https://en.wikipedia.org/wiki/1971_Cannes_Film_Festival', 'cannes', 1971)
# ('https://en.wikipedia.org/wiki/1972_Cannes_Film_Festival', 'cannes', 1972)
# ('https://en.wikipedia.org/wiki/1973_Cannes_Film_Festival', 'cannes', 1973)
# ('https://en.wikipedia.org/wiki/1974_Cannes_Film_Festival', 'cannes', 1974)
# ('https://en.wikipedia.org/wiki/1975_Cannes_Film_Festival', 'cannes', 1975)
# ('https://en.wikipedia.org/wiki/1976_Cannes_Film_Festival', 'cannes', 1976)
# ('https://en.wikipedia.org/wiki/1977_Cannes_Film_Festival', 'cannes', 1977)
# ('https://en.wikipedia.org/wiki/1978_Cannes_Film_Festival', 'cannes', 1978)
# ('https://en.wikipedia.org/wiki/1979_Cannes_Film_Festival', 'cannes', 1979)
# ('https://en.wikipedia.org/wiki/1981_Cannes_Film_Festival', 'cannes', 1981)
# ('https://en.wikipedia.org/wiki/1982_Cannes_Film_Festival', 'cannes', 1982)
# ('https://en.wikipedia.org/wiki/1983_Cannes_Film_Festival', 'cannes', 1983)
# ('https://en.wikipedia.org/wiki/1984_Cannes_Film_Festival', 'cannes', 1984)
# ('https://en.wikipedia.org/wiki/1986_Cannes_Film_Festival', 'cannes', 1986)
# ('https://en.wikipedia.org/wiki/1987_Cannes_Film_Festival', 'cannes', 1987)
# ('https://en.wikipedia.org/wiki/1988_Cannes_Film_Festival', 'cannes', 1988)
# ('https://en.wikipedia.org/wiki/1989_Cannes_Film_Festival', 'cannes', 1989)
# ('https://en.wikipedia.org/wiki/1990_Cannes_Film_Festival', 'cannes', 1990)
# ('https://en.wikipedia.org/wiki/1992_Cannes_Film_Festival', 'cannes', 1992)
# ('https://en.wikipedia.org/wiki/1995_Cannes_Film_Festival', 'cannes', 1995)
# ('https://en.wikipedia.org/wiki/1996_Cannes_Film_Festival', 'cannes', 1996)
# ('https://en.wikipedia.org/wiki/1997_Cannes_Film_Festival', 'cannes', 1997)
# ('https://en.wikipedia.org/wiki/1998_Cannes_Film_Festival', 'cannes', 1998)
# ('https://en.wikipedia.org/wiki/1999_Cannes_Film_Festival', 'cannes', 1999)
# ('https://en.wikipedia.org/wiki/2000_Cannes_Film_Festival', 'cannes', 2000)
# ('https://en.wikipedia.org/wiki/2001_Cannes_Film_Festival', 'cannes', 2001)
# ('https://en.wikipedia.org/wiki/2002_Cannes_Film_Festival', 'cannes', 2002)
# ('https://en.wikipedia.org/wiki/2003_Cannes_Film_Festival', 'cannes', 2003)
# ('https://en.wikipedia.org/wiki/2004_Cannes_Film_Festival', 'cannes', 2004)
# ('https://en.wikipedia.org/wiki/2005_Cannes_Film_Festival', 'cannes', 2005)
# ('https://en.wikipedia.org/wiki/2006_Cannes_Film_Festival', 'cannes', 2006)
# ('https://en.wikipedia.org/wiki/2nd_Venice_International_Film_Festival', 'venice', 1934)
# ('https://en.wikipedia.org/wiki/3rd_Venice_International_Film_Festival', 'venice', 1935)
# ('https://en.wikipedia.org/wiki/4th_Venice_International_Film_Festival', 'venice', 1936)
# ('https://en.wikipedia.org/wiki/5th_Venice_International_Film_Festival', 'venice', 1937)
# ('https://en.wikipedia.org/wiki/6th_Venice_International_Film_Festival', 'venice', 1938)
# ('https://en.wikipedia.org/wiki/30th_Venice_International_Film_Festival', 'venice', 1969)
# ('https://en.wikipedia.org/wiki/31st_Venice_International_Film_Festival', 'venice', 1970)
# ('https://en.wikipedia.org/wiki/32nd_Venice_International_Film_Festival', 'venice', 1971)
# ('https://en.wikipedia.org/wiki/33rd_Venice_International_Film_Festival', 'venice', 1972)
# ('https://en.wikipedia.org/wiki/36th_Venice_International_Film_Festival', 'venice', 1979)

# %%
df_festival
# Out:
#                             title_english  \
# 0                         Adieu Bonaparte
# 1                                   Birdy
# 2                                   Bliss
# 3                    Chicken with Vinegar
# 4                       The Coca-Cola Kid
# 5                            Colonel Redl
# 6                              Derborence
# 7                               Détective
# 8                     Farewell to the Ark
# 9                          Insignificance
# 10                    Joshua Then and Now
# 11               Kiss of the Spider Woman
# 12                     The Official Story
# 13                          Madman at War
# 14                                   Mask
# 15       Mishima: A Life in Four Chapters
# 16                             Pale Rider
# 17                            Rendez-vous
# 18         The Two Lives of Mattia Pascal
# 19       When Father Was Away on Business
# 20               The Assassin of the Tsar
# 21                        Anna Karamazoff
# 22                            Barton Fink
# 23                      La Belle Noiseuse
# 24                                    Bix
# 25                              Cold Moon
# 26           The Double Life of Véronique
# 27                                 Europa
# 28                              The Flesh
# 29                    Guilty by Suspicion
# ...                                   ...
# 4391                              Jezebel
# 4392                 Luciano Serra pilota
# 4393                     Marie Antoinette
# 4394    Olympia 1. Teil - Fest der Völker
# 4395                 Prison sans barreaux
# 4396                            Pygmalion
# 4397      Snow White and the Seven Dwarfs
# 4398                    Fellini Satyricon
# 4399          La primera carga al machete
# 4400                               Zaseda
# 4401                  Blood of the Condor
# 4402                         Čest a sláva
# 4403                            Cardillac
# 4404                                Wanda
# 4405                           The Clowns
# 4406                           The Devils
# 4407                           La vacanza
# 4408                            The Guest
# 4409                       The Last Movie
# 4410                              The Cow
# 4411                        The Cruel Sea
# 4412                          Seemabaddha
# 4413                   A Clockwork Orange
# 4414                         My Childhood
# 4415           Les deux saisons de la vie
# 4416                    Le passe-montagne
# 4417  La nouba des femmes du mont Chenoua
# 4418                      Autumn Marathon
# 4419                       The Strangling
# 4420                           Saint Jack
#
#                             title_original  \
# 0                            وداعا بونابرت
# 1                                      N/A
# 2                                      N/A
# 3                       Poulet au vinaigre
# 4                                      N/A
# 5                              Oberst Redl
# 6                                      N/A
# 7                                Détective
# 8                                    さらば箱舟
# 9                                      N/A
# 10                                     N/A
# 11                O Beijo da Mulher Aranha
# 12                     La historia oficial
# 13                         Scemo di guerra
# 14                                     N/A
# 15                                     N/A
# 16                                     N/A
# 17                                     N/A
# 18            Le due vite di Mattia Pascal
# 19                  Отац на службеном путу
# 20                            Tsareubiytsa
# 21                                     N/A
# 22                                     N/A
# 23                                     N/A
# 24                                     N/A
# 25                             Lune froide
# 26              La double vie de Véronique
# 27                                     N/A
# 28                                La carne
# 29                                     N/A
# ...                                    ...
# 4391                                   N/A
# 4392                                   N/A
# 4393                                   N/A
# 4394  Olympia 2. Teil - Fest der Schönheit
# 4395                                   N/A
# 4396                                   N/A
# 4397                                   N/A
# 4398                                   N/A
# 4399                                   N/A
# 4400                                   N/A
# 4401                                   N/A
# 4402                                   N/A
# 4403                                   N/A
# 4404                                   N/A
# 4405                                   N/A
# 4406                                   N/A
# 4407                                   N/A
# 4408                                   N/A
# 4409                                   N/A
# 4410                                   N/A
# 4411                                   N/A
# 4412                                   N/A
# 4413                                   N/A
# 4414                                   N/A
# 4415                                   N/A
# 4416                                   N/A
# 4417                                   N/A
# 4418                                   N/A
# 4419                                   N/A
# 4420                                   N/A
#
#                                                director  \
# 0                                       Youssef Chahine
# 1                                           Alan Parker
# 2                                          Ray Lawrence
# 3                                        Claude Chabrol
# 4                                       Dušan Makavejev
# 5                                          István Szabó
# 6                                       Francis Reusser
# 7                                       Jean-Luc Godard
# 8                                        Shūji Terayama
# 9                                          Nicolas Roeg
# 10                                         Ted Kotcheff
# 11                                       Héctor Babenco
# 12                                          Luis Puenzo
# 13                                            Dino Risi
# 14                                    Peter Bogdanovich
# 15                                        Paul Schrader
# 16                                       Clint Eastwood
# 17                                        André Téchiné
# 18                                      Mario Monicelli
# 19                                       Emir Kusturica
# 20                                   Karen Shakhnazarov
# 21                                     Rustam Khamdamov
# 22                             Joel Coen and Ethan Coen
# 23                                      Jacques Rivette
# 24                                           Pupi Avati
# 25                                    Patrick Bouchitey
# 26                                 Krzysztof Kieślowski
# 27                                       Lars von Trier
# 28                                        Marco Ferreri
# 29                                        Irwin Winkler
# ...                                                 ...
# 4391                                      William Wyler
# 4392                              Goffredo Alessandrini
# 4393                                     W. S. Van Dyke
# 4394                                   Leni Riefenstahl
# 4395                                      Léonide Moguy
# 4396                     Anthony Asquith, Leslie Howard
# 4397  Walt Disney, Wilfred Jackson, Ben Sharpsteen, ...
# 4398                                   Federico Fellini
# 4399                               Manuel Octavio Gómez
# 4400                                   Zivojin Pavlovic
# 4401                                     Jorge Sanjinés
# 4402                                                N/A
# 4403                                        Edgar Reitz
# 4404                                      Barbara Loden
# 4405                                   Federico Fellini
# 4406                                        Ken Russell
# 4407                                        Tinto Brass
# 4408                                     Liliana Cavani
# 4409                                      Dennis Hopper
# 4410                                    Dariush Mehrjui
# 4411                                                N/A
# 4412                                       Satyajit Ray
# 4413                                    Stanley Kubrick
# 4414                                       Bill Douglas
# 4415                                         Samy Pavel
# 4416                             Jean-François Stévenin
# 4417                                       Assia Djebar
# 4418                                   Georgiy Daneliya
# 4419                                      Kaneto Shindô
# 4420                                  Peter Bogdanovich
#
#                                                 country winner festival  \
# 0                                                 Egypt      0   cannes
# 1                                         United States      0   cannes
# 2                                             Australia      0   cannes
# 3                                                France      0   cannes
# 4                                             Australia      0   cannes
# 5                                               Hungary      0   cannes
# 6                                           Switzerland      0   cannes
# 7                                                France      0   cannes
# 8                                                 Japan      0   cannes
# 9                                        United Kingdom      0   cannes
# 10                                               Canada      0   cannes
# 11                                               Brazil      0   cannes
# 12                                            Argentina      0   cannes
# 13                                                Italy      0   cannes
# 14                                        United States      0   cannes
# 15                                        United States      0   cannes
# 16                                        United States      0   cannes
# 17                                               France      0   cannes
# 18                                                Italy      0   cannes
# 19                                           Yugoslavia      1   cannes
# 20                                         Soviet Union      0   cannes
# 21                                         Soviet Union      0   cannes
# 22                                        United States      1   cannes
# 23                                 France / Switzerland      0   cannes
# 24                                                Italy      0   cannes
# 25                                               France      0   cannes
# 26                             Poland / France / Norway      0   cannes
# 27    Denmark / France / Germany / Sweden / Switzerland      0   cannes
# 28                                                Italy      0   cannes
# 29                               United States / France      0   cannes
# ...                                                 ...    ...      ...
# 4391                                                N/A      0   venice
# 4392                                                N/A      0   venice
# 4393                                                N/A      0   venice
# 4394                                                N/A      0   venice
# 4395                                                N/A      0   venice
# 4396                                                N/A      0   venice
# 4397                                                N/A      0   venice
# 4398                                                N/A      0   venice
# 4399                                                N/A      0   venice
# 4400                                                N/A      0   venice
# 4401                                                N/A      0   venice
# 4402                                                N/A      0   venice
# 4403                                                N/A      0   venice
# 4404                                                N/A      0   venice
# 4405                                                N/A      0   venice
# 4406                                                N/A      0   venice
# 4407                                                N/A      0   venice
# 4408                                                N/A      0   venice
# 4409                                                N/A      0   venice
# 4410                                                N/A      0   venice
# 4411                                                N/A      0   venice
# 4412                                                N/A      0   venice
# 4413                                                N/A      0   venice
# 4414                                                N/A      0   venice
# 4415                                                N/A      0   venice
# 4416                                                N/A      0   venice
# 4417                                                N/A      0   venice
# 4418                                                N/A      0   venice
# 4419                                                N/A      0   venice
# 4420                                                N/A      0   venice
#
#      year_festival                                          link_film  \
# 0             1985      https://en.wikipedia.org/wiki/Adieu_Bonaparte
# 1             1985         https://en.wikipedia.org/wiki/Birdy_(film)
# 2             1985    https://en.wikipedia.org/wiki/Bliss_(1985_film)
# 3             1985  https://en.wikipedia.org/wiki/Chicken_with_Vin...
# 4             1985    https://en.wikipedia.org/wiki/The_Coca-Cola_Kid
# 5             1985         https://en.wikipedia.org/wiki/Colonel_Redl
# 6             1985    https://en.wikipedia.org/wiki/Derborence_(film)
# 7             1985  https://en.wikipedia.org/wiki/D%C3%A9tective_(...
# 8             1985  https://en.wikipedia.org/wiki/Farewell_to_the_Ark
# 9             1985  https://en.wikipedia.org/wiki/Insignificance_(...
# 10            1985  https://en.wikipedia.org/wiki/Joshua_Then_and_...
# 11            1985  https://en.wikipedia.org/wiki/Kiss_of_the_Spid...
# 12            1985   https://en.wikipedia.org/wiki/The_Official_Story
# 13            1985        https://en.wikipedia.org/wiki/Madman_at_War
# 14            1985     https://en.wikipedia.org/wiki/Mask_(1985_film)
# 15            1985  https://en.wikipedia.org/wiki/Mishima:_A_Life_...
# 16            1985           https://en.wikipedia.org/wiki/Pale_Rider
# 17            1985   https://en.wikipedia.org/wiki/Rendez-vous_(film)
# 18            1985  https://en.wikipedia.org/wiki/The_Two_Lives_of...
# 19            1985  https://en.wikipedia.org/wiki/When_Father_Was_...
# 20            1991  https://en.wikipedia.org/wiki/The_Assassin_of_...
# 21            1991      https://en.wikipedia.org/wiki/Anna_Karamazoff
# 22            1991          https://en.wikipedia.org/wiki/Barton_Fink
# 23            1991    https://en.wikipedia.org/wiki/La_Belle_Noiseuse
# 24            1991           https://en.wikipedia.org/wiki/Bix_(film)
# 25            1991            https://en.wikipedia.org/wiki/Cold_Moon
# 26            1991  https://en.wikipedia.org/wiki/The_Double_Life_...
# 27            1991        https://en.wikipedia.org/wiki/Europa_(film)
# 28            1991            https://en.wikipedia.org/wiki/The_Flesh
# 29            1991  https://en.wikipedia.org/wiki/Guilty_by_Suspicion
# ...            ...                                                ...
# 4391          1938  https://en.wikipedia.org/wiki/Jezebel_(1938_film)
# 4392          1938  https://en.wikipedia.org/wiki/Luciano_Serra,_P...
# 4393          1938  https://en.wikipedia.org/wiki/Marie_Antoinette...
# 4394          1938  https://en.wikipedia.org/wiki/Olympia_(1938_film)
# 4395          1938  https://en.wikipedia.org/wiki/Prison_sans_barr...
# 4396          1938  https://en.wikipedia.org/wiki/Pygmalion_(1938_...
# 4397          1938  https://en.wikipedia.org/wiki/Snow_White_and_t...
# 4398          1969    https://en.wikipedia.org/wiki/Fellini_Satyricon
# 4399          1969                                                N/A
# 4400          1969                                                N/A
# 4401          1969  https://en.wikipedia.org/wiki/Blood_of_the_Condor
# 4402          1969                                                N/A
# 4403          1969     https://en.wikipedia.org/wiki/Cardillac_(film)
# 4404          1970         https://en.wikipedia.org/wiki/Wanda_(film)
# 4405          1970    https://en.wikipedia.org/wiki/The_Clowns_(film)
# 4406          1971    https://en.wikipedia.org/wiki/The_Devils_(film)
# 4407          1971           https://en.wikipedia.org/wiki/La_vacanza
# 4408          1971                                                N/A
# 4409          1971       https://en.wikipedia.org/wiki/The_Last_Movie
# 4410          1971  https://en.wikipedia.org/wiki/The_Cow_(1969_film)
# 4411          1972  https://en.wikipedia.org/wiki/The_Cruel_Sea_(1...
# 4412          1972          https://en.wikipedia.org/wiki/Seemabaddha
# 4413          1972  https://en.wikipedia.org/wiki/A_Clockwork_Oran...
# 4414          1972                                                N/A
# 4415          1972                                                N/A
# 4416          1979                                                N/A
# 4417          1979                                                N/A
# 4418          1979      https://en.wikipedia.org/wiki/Autumn_Marathon
# 4419          1979                                                N/A
# 4420          1979    https://en.wikipedia.org/wiki/Saint_Jack_(film)
#
#                                           link_director
# 0        https://en.wikipedia.org/wiki/Youssef_Chahine
# 1            https://en.wikipedia.org/wiki/Alan_Parker
# 2     https://en.wikipedia.org/wiki/Ray_Lawrence_(fi...
# 3         https://en.wikipedia.org/wiki/Claude_Chabrol
# 4     https://en.wikipedia.org/wiki/Du%C5%A1an_Makav...
# 5     https://en.wikipedia.org/wiki/Istv%C3%A1n_Szab...
# 6        https://en.wikipedia.org/wiki/Francis_Reusser
# 7        https://en.wikipedia.org/wiki/Jean-Luc_Godard
# 8     https://en.wikipedia.org/wiki/Sh%C5%ABji_Teray...
# 9           https://en.wikipedia.org/wiki/Nicolas_Roeg
# 10          https://en.wikipedia.org/wiki/Ted_Kotcheff
# 11    https://en.wikipedia.org/wiki/H%C3%A9ctor_Babe...
# 12           https://en.wikipedia.org/wiki/Luis_Puenzo
# 13             https://en.wikipedia.org/wiki/Dino_Risi
# 14     https://en.wikipedia.org/wiki/Peter_Bogdanovich
# 15         https://en.wikipedia.org/wiki/Paul_Schrader
# 16        https://en.wikipedia.org/wiki/Clint_Eastwood
# 17    https://en.wikipedia.org/wiki/Andr%C3%A9_T%C3%...
# 18       https://en.wikipedia.org/wiki/Mario_Monicelli
# 19        https://en.wikipedia.org/wiki/Emir_Kusturica
# 20    https://en.wikipedia.org/wiki/Karen_Shakhnazarov
# 21      https://en.wikipedia.org/wiki/Rustam_Khamdamov
# 22         https://en.wikipedia.org/wiki/Coen_brothers
# 23       https://en.wikipedia.org/wiki/Jacques_Rivette
# 24            https://en.wikipedia.org/wiki/Pupi_Avati
# 25     https://en.wikipedia.org/wiki/Patrick_Bouchitey
# 26    https://en.wikipedia.org/wiki/Krzysztof_Kie%C5...
# 27        https://en.wikipedia.org/wiki/Lars_von_Trier
# 28         https://en.wikipedia.org/wiki/Marco_Ferreri
# 29         https://en.wikipedia.org/wiki/Irwin_Winkler
# ...                                                 ...
# 4391        https://en.wikipedia.org/wiki/William_Wyler
# 4392  https://en.wikipedia.org/wiki/Goffredo_Alessan...
# 4393       https://en.wikipedia.org/wiki/W._S._Van_Dyke
# 4394     https://en.wikipedia.org/wiki/Leni_Riefenstahl
# 4395   https://en.wikipedia.org/wiki/L%C3%A9onide_Moguy
# 4396  https://en.wikipedia.org/wiki/Anthony_Asquith ...
# 4397  https://en.wikipedia.org/wiki/Walt_Disney http...
# 4398     https://en.wikipedia.org/wiki/Federico_Fellini
# 4399  https://en.wikipedia.org/wiki/Manuel_Octavio_G...
# 4400     https://en.wikipedia.org/wiki/Zivojin_Pavlovic
# 4401  https://en.wikipedia.org/wiki/Jorge_Sanjin%C3%A9s
# 4402                                                N/A
# 4403          https://en.wikipedia.org/wiki/Edgar_Reitz
# 4404        https://en.wikipedia.org/wiki/Barbara_Loden
# 4405     https://en.wikipedia.org/wiki/Federico_Fellini
# 4406          https://en.wikipedia.org/wiki/Ken_Russell
# 4407          https://en.wikipedia.org/wiki/Tinto_Brass
# 4408       https://en.wikipedia.org/wiki/Liliana_Cavani
# 4409        https://en.wikipedia.org/wiki/Dennis_Hopper
# 4410      https://en.wikipedia.org/wiki/Dariush_Mehrjui
# 4411                                                N/A
# 4412         https://en.wikipedia.org/wiki/Satyajit_Ray
# 4413      https://en.wikipedia.org/wiki/Stanley_Kubrick
# 4414         https://en.wikipedia.org/wiki/Bill_Douglas
# 4415  https://en.wikipedia.org/w/index.php?title=Sam...
# 4416  https://en.wikipedia.org/wiki/Jean-Fran%C3%A7o...
# 4417         https://en.wikipedia.org/wiki/Assia_Djebar
# 4418     https://en.wikipedia.org/wiki/Georgiy_Daneliya
# 4419   https://en.wikipedia.org/wiki/Kaneto_Shind%C3%B4
# 4420    https://en.wikipedia.org/wiki/Peter_Bogdanovich
#
# [4421 rows x 9 columns]

# %% [markdown]
# #### Manual

# %%
# CANNES
# table: 1985, 1991, 1993 to 1994, 2007 to 2019, inclusive
# bullet: 1949 ("directed by"), 1952 to 1967, 1969 to 1979, 1981 to 1984, 1986 to 1990, 1992, 1995 to 2006, inclusive
# exceptions: 1946 (films fine, awards manual, "directed by"), 1947 (films fine, awards manual), 1948 (nonexistent), 1950 (nonexistent), 1951 (films fine, awards manual), 1968 (films fine, no awards given), 1980 (diff tag format, manual)

# VENICE
# table: 1939, 1947 to 1968, 1980 to 2019, inclusive
# bullet: 1934 to 1938, 1969 to 1972, 1979, inclusive
# exceptions: 1932 (films not available, so treat as nonexistent, will not include in dataset) 1969 (country), 1970 (country), 1971 (country), 1972 (country), 1979 (country)

# BERLIN
# table: 1951 to 2009, 2011 to 2019, inclusive
# bullet: none
# exceptions: 2010 (diff table format, manual)

# %%
# 1946 Cannes

url_cannes_1946 = 'https://en.wikipedia.org/wiki/1946_Cannes_Film_Festival'
r_cannes_1946 = requests.get(url_cannes_1946)
soup_cannes_1946 = BeautifulSoup(r_cannes_1946.content, 'lxml')

palmedor = [] # all links associated to the Palme d'Or
for child in soup_cannes_1946.find('span', {'id': "Official_awards"}).parent.find_next_sibling('ul').find('a', {'title': "Palme d'Or"}).parent.ul.find_all('a'):
    palmedor.append('https://en.wikipedia.org' + child['href'])
link_film = df_festival.loc[(df_festival['festival'] == 'cannes') & (df_festival['year_festival'] == 1946)]['link_film']
winner = [1 if link in palmedor else 0 for link in link_film]
df_festival.loc[(df_festival['festival'] == 'cannes') & (df_festival['year_festival'] == 1946), 'winner'] = winner

# %%
# 1947 Cannes

url_cannes_1947 = 'https://en.wikipedia.org/wiki/1947_Cannes_Film_Festival'
r_cannes_1947 = requests.get(url_cannes_1947)
soup_cannes_1947 = BeautifulSoup(r_cannes_1947.content, 'lxml')

palmedor = [] # all links associated to the Palme d'Or
for child in soup_cannes_1947.find('span', {'id': "Awards"}).parent.find_next_sibling('ul').find_all('a'):
    palmedor.append('https://en.wikipedia.org' + child['href'])
link_film = df_festival.loc[(df_festival['festival'] == 'cannes') & (df_festival['year_festival'] == 1947)]['link_film']
winner = [1 if link in palmedor else 0 for link in link_film]
df_festival.loc[(df_festival['festival'] == 'cannes') & (df_festival['year_festival'] == 1947), 'winner'] = winner
df_festival.loc[df_festival['title_english'] == 'Antoine et Antoinette', 'winner'] = 1

# %%
# 1951 Cannes

url_cannes_1951 = 'https://en.wikipedia.org/wiki/1951_Cannes_Film_Festival'
r_cannes_1951 = requests.get(url_cannes_1951)
soup_cannes_1951 = BeautifulSoup(r_cannes_1951.content, 'lxml')

palmedor = [] # all links associated to the Palme d'Or
for child in soup_cannes_1951.find('span', {'id': "Awards"}).parent.find_next_sibling('ul').find('a', {'title': "Palme d'Or"}).parent.ul.find_all('a'):
    palmedor.append('https://en.wikipedia.org' + child['href'])
link_film = df_festival.loc[(df_festival['festival'] == 'cannes') & (df_festival['year_festival'] == 1951)]['link_film']
winner = [1 if link in palmedor else 0 for link in link_film]
df_festival.loc[(df_festival['festival'] == 'cannes') & (df_festival['year_festival'] == 1951), 'winner'] = winner

# %%
# 1980 Cannes

url_cannes_1980 = 'https://en.wikipedia.org/wiki/1980_Cannes_Film_Festival'
r_cannes_1980 = requests.get(url_cannes_1980)
soup_cannes_1980 = BeautifulSoup(r_cannes_1980.content, 'lxml')

title_english = []
director = []
link_film = []
link_director = []

for child in soup_cannes_1980.find('span', {'id': "In_competition_-_Feature_film"}).parent.find_next_sibling('ul').find_all('li'):
    title_english.append(child.get_text().split(' by ')[0] if child.get_text() else 'N/A')
    director.append(child.get_text().split(' by ')[1] if child.get_text() else 'N/A')
    
    links = ['https://en.wikipedia.org' + a['href'] for a in child.find_all('a')]
    link_film.append(links[0] if links else 'N/A')
    links_string = ''
    for i in range(1, len(links)):
        links_string += links[i] + ' '
    link_director.append(links_string if links else 'N/A')

title_english = [title.strip(' ') for title in title_english]
director = [d.strip(' ') for d in director]
link_director = [link.strip(' ') for link in link_director]

palmedor = [] # all links associated to the Palme d'Or
for child in soup_cannes_1980.find('span', {'id': "Official_awards"}).parent.find_next_sibling('ul').find('a', {'title': "Palme d'Or"}).parent.ul.find_all('a'):
    palmedor.append('https://en.wikipedia.org' + child['href'])
winner = [1 if link in palmedor else 0 for link in link_film]

df_cannes_1980 = pd.DataFrame({'title_english': title_english,
                               'title_original': 'N/A',
                               'director': director,
                               'country': 'N/A',
                               'winner': winner,
                               'festival': 'cannes',
                               'year_festival': 1980,
                               'link_film': link_film,
                               'link_director': link_director})

df_festival = df_festival.append(df_cannes_1980, ignore_index=True)

# %%
# 2010 Berlin

url_berlin_2010 = 'https://en.wikipedia.org/wiki/60th_Berlin_International_Film_Festival'
r_berlin_2010 = requests.get(url_berlin_2010)
soup_berlin_2010 = BeautifulSoup(r_berlin_2010.content, 'lxml')
tables = soup_berlin_2010.findAll('table', {'class': 'wikitable'})
    
title_english = []
director = []
country = []
winner = []
link_film = []
link_director = []

trs = tables[0].find_all('tr')[1:]
for tr in trs:
    tds = tr.find_all('td')
    
    title_english.append(tds[0].find('i').get_text() if tds[0].find('i') else 'N/A')
    director.append(tds[1].get_text().strip('\n'))
    country.append(tds[2].span['data-sort-value'])
    
    link_film.append('https://en.wikipedia.org' + tds[0].find('a').get('href'))
    
    links = tds[1].find_all('a')
    links_string = ''
    for link in links:
        links_string += 'https://en.wikipedia.org' + link.get('href') + ' '
    link_director.append(links_string if links else 'N/A')
    
    # winner
    if tr.has_attr('style'):
        winner.append(1)
    else:
        winner.append(0)

df_berlin_2010 = pd.DataFrame({'title_english': title_english,
                               'title_original': 'N/A',
                               'director': director,
                               'country': country,
                               'winner': winner,
                               'festival': 'berlin',
                               'year_festival': 2010,
                               'link_film': link_film,
                               'link_director': link_director,})

df_festival = df_festival.append(df_berlin_2010, ignore_index=True)

# %%
df_festival['title_english'] = [title.strip(' ') for title in df_festival['title_english']]
df_festival['title_original'] = [title.strip(' ') for title in df_festival['title_original']]
df_festival['director'] = [d.strip(' ') for d in df_festival['director']]
df_festival['country'] = [c.strip(' ') for c in df_festival['country']]
df_festival['link_film'] = [link_f.strip(' ') for link_f in df_festival['link_film']]
df_festival['link_director'] = [link_d.strip(' ') for link_d in df_festival['link_director']]

# %%
df_festival.to_csv('./data/festivals.csv', index_label='id')
